# %% [markdown]
# ![](https://github.com/muellerzr/Practical-Deep-Learning-for-Coders-2.0/blob/master/walkwithfastai.png?raw=true)
#
# ## About this course/study group:
# * It's a hybrid
# * Like Practical Deep Learning for Coders but many bonuses
# * Spans 2-3 hours depending on who stays with 1-1.5 hour lectures
#
# ## About Me:
# * Been doing fastai for 1.5 years
# * A few projects (some involving fastai, some not)
# * University undergraduate, Software Design and Development with a minor in ES
#
# ## Why did I make this?
# * Make fastai accessable to Undergraduates at my school (University of West Florida)
# * We both learn
# * Techniques not mentioned in the course

# %% [markdown]
# # Course Schedule
#
# **BLOCKS**:
# * Block 1: Computer Vision
# * Block 2: Tabular Neural Networks
# * Block 3: Natural Language Processing
#
# **Block 1** (January 15th - February 26th):
# * **Lesson 1: PETs and Custom Datasets (a warm introduction to the DataBlock API)**
# * Lesson 2: Image Classification Models from Scratch, Stochastic Gradient Descent
# * Lesson 3: Multi-Label Classification, and Dealing with Unknown Labels
# * Lesson 4: Image Segmentation, State-of-the-Art in Computer Vision
# * Lesson 5: Style Transfer, `nbdev`, and Deployment
# * Lesson 6: Keypoint Regression and Pose Detection
# * Lesson 7: Image Generation and Object Detection
# * Lesson 8: Audio
#
# **Block 2** (March 4th - March 25th):
# * Lesson 1: Pandas Workshop and Tabular Classification
# * Lesson 2: Feature Engineering and Tabular Regression
# * Lesson 3: Permutation Importance, Bayesian Optimization, Cross-Validation, and Labeled Test Sets
# * Lesson 4: NODE, TabNet, DeepGBM
#
# **BLOCK 3** (April 1st - April 22nd):
# * Lesson 1: Introduction to NLP and the LSTM
# * Lesson 2: Full Sentiment Classification, Tokenizers, and Ensembling
# * Lesson 3: Other State-of-the-Art NLP Models
# * Lesson 4: Multi-Lingual Data, DeViSe
#
# Looks very intense, if you don't keep up it's okay. Lectures are recorded.

# %% [markdown]
# # Requirements:
#
# * A Google account to use Google Colaboratory (what I am in right now)
# * A Paperspace account for Natural Language Processing

# %% [markdown]
# # Communication
# * Key to making study groups work!
# * We have a dedicated mega-thread on the fastai forums [here](https://forums.fast.ai/t/a-walk-with-fastai-study-group-and-online-lectures-megathread/59929) for us to use!
# * No question is too stupid!

# %% [markdown]
# # Enough intro, can I learn already?

# %% [markdown]
# # Environment setup
#
# Google Colaboratory - Free GPU's
#
# Go to [here](colab.research.google.com) to start using it.

# %% [markdown]
# File -> Open notebook

# %% [markdown]
# ![](https://i.imgur.com/pGCkS9G.png)

# %% [markdown]
# Select from GitHub and use the following URL: muellerzr/A-walk-with-fastai

# %% [markdown]
# ![](https://i.imgur.com/9O1LMZt.png)

# %% [markdown]
# Choose open in a new tab

# %% [markdown]
# ![](https://i.imgur.com/NuL67k9.png)

# %% [markdown]
# And now your screen looks similar to below! (With what I am using instead)

# %% [markdown]
# ![alt text](https://i.imgur.com/n4mQ2qj.png)

# %% [markdown]
# ## Changing our processer to a GPU

# %% [markdown]
# * 'Runtime'
# * 'Change runtime type'
# * 'Runtime type' should be 'Python 3'
# * 'Hardware accelerator' should be 'GPU'

# %% [markdown]
# ## Initial Run Warning (For pulling from GitHub)

# %% [markdown]
# ***If you get a pop up saying 'Warning: This notebook was not authored by Google,' check 'Reset all runtimes before running' and click 'Run Anyway'***

# %% [markdown]
# ![alt text](https://course.fast.ai/images/colab/02.png)

# %% [markdown]
# ## Saving your work
#
# For now this will just save the notebook on their cloud, we will look next week how to utilize your Google Drives!

# %% [markdown]
# ![alt text](https://course.fast.ai/images/colab/09.png)

# %% [markdown]
# # What is fastai?
#
# * Neural-network based library
# * Helps make state-of-the-art more accessible
# * Supports five datatypes:
#   * Computer vision (fastai.vision)
#   * Tabular data (fastai.tabular)
#   * Text (fastai.text)
#   * Collaborative filtering (fastai.collab) - **not going over**

# %% [markdown]
# # What is our goal today?
#
# * Make an image classifier for Cats and Dogs
# * Make our own image classifier
# * Start to understand the DataBlock API

# %% [markdown]
# # Let's grab the library:

# %%
#Run once per session
#!pip install fastai -q

# %% [markdown]
# Now we can import the `fastai` libraries (fastai 2.0!)
#
# Today we will be using the `basics`, `callback`, and `vision` libraries as we have a **vision** task

# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 727kB 2.6MB/s
#      |████████████████████████████████| 51kB 6.5MB/s
#      |████████████████████████████████| 51kB 5.5MB/s
#      |████████████████████████████████| 194kB 10.1MB/s
#      |████████████████████████████████| 1.0MB 13.4MB/s
#      |████████████████████████████████| 40kB 5.9MB/s
#      |████████████████████████████████| 92kB 9.0MB/s
#      |████████████████████████████████| 40kB 5.7MB/s
#      |████████████████████████████████| 61kB 7.6MB/s
#      |████████████████████████████████| 51kB 7.7MB/s
#      |████████████████████████████████| 2.6MB 15.6MB/s
# Mounted at /content/gdrive

# %%
#hide
from fastbook import *

# %%
#from fastai.vision.all import *

# %%
from fastai.basics import *
from fastai.vision.all import *
from fastai.callback.all import *

# %% [markdown]
# Overall process using machine learning models and fastai:
# 1. Make our `DataLoaders`
# 2. Make a `Learner` with some "equipment"
# 3. Train

# %% [markdown]
# ## Looking at Data

# %% [markdown]
# We'll be trying to identify between 12 species of cats and 25 species of dogs (37 in total). Five years ago, the best was 59% with seperate classifications for the image, head, and body of the animal. Let's try just doing one image for everything.
#
# But before anything, we need data!

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.data.external:
#
# untar_data(url, fname=None, dest=None, c_key='data', force_download=False, extract_func=<function file_extract at 0x7fde3fa52ea0>)
#     Download `url` to `fname` if `dest` doesn't exist, and un-tgz or unzip to folder `dest`.

# %%
untar_data??

# %% [markdown]
# Let's download the dataset

# %%
path = untar_data(URLs.PETS)

# %% [markdown]
# And set our seed

# %%
np.random.seed(2)

# %% [markdown]
# How will our data look?

# %%
path.ls()[:3]
# Out:
# (#2) [Path('/root/.fastai/data/oxford-iiit-pet/images'),Path('/root/.fastai/data/oxford-iiit-pet/annotations')]

# %% [markdown]
# Let's build a `DataLoaders`.

# %%
path = untar_data(URLs.PETS)
fnames = get_image_files(path/'images')
pat = r'(.+)_\d+.jpg$'

# %% [markdown]
# Some  basic transforms

# %%
batch_tfms = [*aug_transforms(size=224, max_warp=0), Normalize.from_stats(*imagenet_stats)]
item_tfms = RandomResizedCrop(460, min_scale=0.75, ratio=(1.,1.))
bs=64

# %% [markdown]
# `ImageDataBunch` (renamed to ImageDataLoaders) - highest level API

# %%
dls = ImageDataLoaders.from_name_re(path, fnames, pat, batch_tfms=batch_tfms, 
                                   item_tfms=item_tfms, bs=bs)

# %% [markdown]
# What is the API?
#
# * See PPT

# %%
help(ImageDataLoaders)
# Out:
# Help on class ImageDataLoaders in module fastai.vision.data:
#
# class ImageDataLoaders(fastai.data.core.DataLoaders)
#  |  Basic wrapper around several `DataLoader`s with factory methods for computer vision problems
#  |
#  |  Method resolution order:
#  |      ImageDataLoaders
#  |      fastai.data.core.DataLoaders
#  |      fastcore.foundation.GetAttr
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  from_csv(path, csv_fname='labels.csv', header='infer', delimiter=None, valid_pct=0.2, seed=None, fn_col=0, folder=None, suff='', label_col=1, label_delim=None, y_block=None, valid_col=None, item_tfms=None, batch_tfms=None, bs=64, val_bs=None, shuffle_train=True, device=None) from builtins.type
#  |      Create from `path/csv_fname` using `fn_col` and `label_col`
#  |
#  |  from_name_func(path, fnames, label_func, valid_pct=0.2, seed=None, item_tfms=None, batch_tfms=None, bs=64, val_bs=None, shuffle_train=True, device=None) from builtins.type
#  |      Create from the name attrs of `fnames` in `path`s with `label_func`
#  |
#  |  from_name_re(path, fnames, pat, bs=64, val_bs=None, shuffle_train=True, device=None) from builtins.type
#  |      Create from the name attrs of `fnames` in `path`s with re expression `pat`
#  |
#  |  from_path_re(path, fnames, pat, valid_pct=0.2, seed=None, item_tfms=None, batch_tfms=None, bs=64, val_bs=None, shuffle_train=True, device=None) from builtins.type
#  |      Create from list of `fnames` in `path`s with re expression `pat`
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_df(df, path='.', valid_pct=0.2, seed=None, fn_col=0, folder=None, suff='', label_col=1, label_delim=None, y_block=None, valid_col=None, item_tfms=None, batch_tfms=None, bs=64, val_bs=None, shuffle_train=True, device=None) from builtins.type
#  |      Create from `df` using `fn_col` and `label_col`
#  |
#  |  from_folder(path, train='train', valid='valid', valid_pct=None, seed=None, vocab=None, item_tfms=None, batch_tfms=None, bs=64, val_bs=None, shuffle_train=True, device=None) from builtins.type
#  |      Create from imagenet style dataset in `path` with `train` and `valid` subfolders (or provide `valid_pct`)
#  |
#  |  from_lists(path, fnames, labels, valid_pct=0.2, seed:int=None, y_block=None, item_tfms=None, batch_tfms=None, bs=64, val_bs=None, shuffle_train=True, device=None) from builtins.type
#  |      Create from list of `fnames` and `labels` in `path`
#  |
#  |  from_path_func(path, fnames, label_func, valid_pct=0.2, seed=None, item_tfms=None, batch_tfms=None, bs=64, val_bs=None, shuffle_train=True, device=None) from builtins.type
#  |      Create from list of `fnames` in `path`s with `label_func`
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from fastai.data.core.DataLoaders:
#  |
#  |  __getitem__(self, i)
#  |      Retrieve `DataLoader` at `i` (`0` is training, `1` is validation)
#  |
#  |  __init__(self, *loaders, path='.', device=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  cpu(self)
#  |      Use the cpu
#  |
#  |  cuda(self)
#  |      Use the gpu if available
#  |
#  |  new_empty(self)
#  |      Create a new empty version of `self` with the same transforms
#  |
#  |  test_dl(self:fastai.data.core.DataLoaders, test_items, rm_type_tfms=None, with_labels=False, **kwargs)
#  |      Create a test dataloader from `test_items` using validation transforms of `dls`
#  |
#  |  to(self, device)
#  |      Use `device`
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from fastai.data.core.DataLoaders:
#  |
#  |  from_dblock(dblock, source, path='.', bs=64, val_bs=None, shuffle_train=True, device=None, **kwargs) from builtins.type
#  |      Create a dataloaders from a given `dblock`
#  |
#  |  from_dsets(*ds, path='.', bs=64, device=None, dl_type=<class 'fastai.data.core.TfmdDL'>, **kwargs) from builtins.type
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from fastai.data.core.DataLoaders:
#  |
#  |  device
#  |
#  |  train
#  |      Training `DataLoader`
#  |
#  |  train_ds
#  |      Training `Dataset`
#  |
#  |  valid
#  |      Validation `DataLoader`
#  |
#  |  valid_ds
#  |      Validation `Dataset`
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from fastcore.foundation.GetAttr:
#  |
#  |  __dir__(self)
#  |      __dir__() -> list
#  |      default dir() implementation
#  |
#  |  __getattr__(self, k)
#  |
#  |  __setstate__(self, data)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from fastcore.foundation.GetAttr:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# Let's rebuild using the `DataBlock` api - Medium Level

# %%
pets = DataBlock(blocks=(ImageBlock, CategoryBlock),
                 get_items=get_image_files,
                 splitter=RandomSplitter(),
                 get_y=RegexLabeller(pat = r'/([^/]+)_\d+.*'),
                 item_tfms=item_tfms,
                 batch_tfms=batch_tfms)

# %%
path_im = path/'images'

# %%
dls = pets.dataloaders(path_im, bs=bs)

# %% [markdown]
# We can take a look at a batch of our images using `show_batch` and pass in a aximum number of images to show, and how large we want to view them as

# %%
dls.show_batch(max_n=9, figsize=(6,7))

# %% [markdown]
# If we want to see how many classes we have, and the names of them we can simply call `dls.vocab`. The first is the number of classes, the second is the names of our classes. You may notice this looks a bit odd, that's because this `L` is a new invention of Jeremy and Sylvian. Essentially it's a Python list taken to the extreme.
#
# Before if we wanted to grab the index for the name of a class (eg. our model output 0 as our class), we would need to use `data.c2i` to grab the Class2Index mapping. This is still here, it lives in `dls.vocab.o2i`

# %%
dls.vocab
# Out:
# (#37) ['Abyssinian','Bengal','Birman','Bombay','British_Shorthair','Egyptian_Mau','Maine_Coon','Persian','Ragdoll','Russian_Blue'...]

# %%
dls.vocab.o2i
# Out:
# {'Abyssinian': 0,
#  'Bengal': 1,
#  'Birman': 2,
#  'Bombay': 3,
#  'British_Shorthair': 4,
#  'Egyptian_Mau': 5,
#  'Maine_Coon': 6,
#  'Persian': 7,
#  'Ragdoll': 8,
#  'Russian_Blue': 9,
#  'Siamese': 10,
#  'Sphynx': 11,
#  'american_bulldog': 12,
#  'american_pit_bull_terrier': 13,
#  'basset_hound': 14,
#  'beagle': 15,
#  'boxer': 16,
#  'chihuahua': 17,
#  'english_cocker_spaniel': 18,
#  'english_setter': 19,
#  'german_shorthaired': 20,
#  'great_pyrenees': 21,
#  'havanese': 22,
#  'japanese_chin': 23,
#  'keeshond': 24,
#  'leonberger': 25,
#  'miniature_pinscher': 26,
#  'newfoundland': 27,
#  'pomeranian': 28,
#  'pug': 29,
#  'saint_bernard': 30,
#  'samoyed': 31,
#  'scottish_terrier': 32,
#  'shiba_inu': 33,
#  'staffordshire_bull_terrier': 34,
#  'wheaten_terrier': 35,
#  'yorkshire_terrier': 36}

# %% [markdown]
# ## Time to make and train a model!

# %% [markdown]
# We will be using a convolutional neural network backbone and a fully connected head with a single hidden layer as our classifier. Don't worry if thats a bunch of nonsense for now. Right now, just know this: we are piggybacking off of a model to help us classify images into 37 categories.

# %% [markdown]
# First, we need to make our Neural Network and our `Learner` like before.
#
# A `Learner` needs (on a base level):
#
# * `DataLoaders`
# * Some architecture
# * A evaluation metric
# * A loss function
# * An optimizer
#
# We'll also use `mixed_precision` (`fp16`)

# %%
learn = cnn_learner(dls, resnet34, pretrained=True, metrics=error_rate).to_fp16()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %% [markdown]
# Some assumptions being made here:
#
# * Loss function is assumed as classification, so `CrossEntropyFlat`
# * Optimizer is assumed to be Adam

# %% [markdown]
# Now, we can train it! We will train it for four cycles through all our data

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.950976</td>
#       <td>0.358739</td>
#       <td>0.117050</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.702728</td>
#       <td>0.240007</td>
#       <td>0.077131</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.384667</td>
#       <td>0.223725</td>
#       <td>0.073072</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.296475</td>
#       <td>0.222447</td>
#       <td>0.071042</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage_1')
# Out:
# Path('models/stage_1.pth')

# %% [markdown]
# ## Lets look at our results

# %% [markdown]
# With the model trained, let's look at where our it might've messed up. What species did it have trouble differentiating between? So long as the misidentifications are not too crazy, our model is actually working.

# %% [markdown]
# Let's plot our losses and make a confusion matrix to visualize this. Below checks to make sure that all pieces we need are available

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

len(dls.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %% [markdown]
# `plot_top_losses` needs `x` number of images to use, and a figure size.

# %%
interp.plot_top_losses(9, figsize=(15,10))

# %% [markdown]
# `plot_confusion_matrix` just needs a figure size. dpi adjusts the quality

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# We can also directly grab our most confused (A raw version of the confusion matrix), and pass in a threshold

# %%
interp.most_confused(min_val=3)
# Out:
# [('Bengal', 'Abyssinian', 4),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 4),
#  ('Birman', 'Ragdoll', 3),
#  ('British_Shorthair', 'Russian_Blue', 3),
#  ('Ragdoll', 'Birman', 3),
#  ('Russian_Blue', 'British_Shorthair', 3),
#  ('beagle', 'basset_hound', 3),
#  ('pug', 'boxer', 3)]

# %% [markdown]
# ## Unfreezing our data, fine-tuning, and our learning rates

# %% [markdown]
# So, we have the model. Let's fine tune it. First, we need to load our model back in.

# %%
learn.load('stage_1');

# %% [markdown]
# Now we will *unfreeze* and train more

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.126151</td>
#       <td>2.892930</td>
#       <td>0.617050</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.083946</td>
#       <td>1.228871</td>
#       <td>0.349797</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.606605</td>
#       <td>0.476014</td>
#       <td>0.150880</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.320820</td>
#       <td>0.396002</td>
#       <td>0.123816</td>
#       <td>01:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now when we `unfreeze`, we unfreeze *all* the layers. So to show how a difference of a proper learning rate looks, let's load in those old weights and try using `lr_find()`

# %%
learn.load('stage_1');

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=7.585775892948732e-06, lr_steep=3.981071586167673e-06)

# %% [markdown]
# Alright so if we look here, we don't start really spiking our losses until ~10^-2 so a good spot is between 1e-6 and 1e-4, let's do that!

# %%
learn.unfreeze()
learn.fit_one_cycle(4, lr_max=slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.276578</td>
#       <td>0.216406</td>
#       <td>0.064953</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.231931</td>
#       <td>0.209550</td>
#       <td>0.072395</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.209524</td>
#       <td>0.207140</td>
#       <td>0.069012</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.183831</td>
#       <td>0.211510</td>
#       <td>0.070365</td>
#       <td>01:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see that picking a proper learning rate can help speed things up!

# %%
learn.save('stage_2')
# Out:
# Path('models/stage_2.pth')

# %% [markdown]
# ## Now lets try with a resnet50!
#
# If you need to restart your kernel due to memory errors I've attached the `dls` code below

# %%
pets = DataBlock(blocks=(ImageBlock, CategoryBlock),
                 get_items=get_image_files,
                 splitter=RandomSplitter(),
                 get_y=RegexLabeller(pat = r'/([^/]+)_\d+.*'),
                 item_tfms=item_tfms,
                 batch_tfms=batch_tfms)

dls = pets.dataloaders(untar_data(URLs.PETS)/"images", bs=32)

# %% [markdown]
# Go ahead and try running the below code yourself. You *should* see a higher increase in accuracy!
#
# Steps to try:
#
# 1. Create your Learner
# 2. Find a learning rate
# 3. Fit for 5 epochs
# 4. Unfreeze and fit for two more

# %%
learn50 = cnn_learner(dls, resnet50, pretrained=True, metrics=error_rate).to_fp16()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
learn50.fit_one_cycle(5)
#learn50.fit_one_cycle(5, lr_max=slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.862159</td>
#       <td>0.299861</td>
#       <td>0.099459</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.426523</td>
#       <td>0.256262</td>
#       <td>0.083897</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.299836</td>
#       <td>0.237547</td>
#       <td>0.073072</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.170555</td>
#       <td>0.215008</td>
#       <td>0.069012</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.129292</td>
#       <td>0.199237</td>
#       <td>0.058863</td>
#       <td>01:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn50.lr_find()
# Out:
# SuggestedLRs(lr_min=1.318256749982538e-07, lr_steep=2.2908675418875646e-06)

# %%
learn50_f = cnn_learner(dls, resnet50, pretrained=True, metrics=error_rate).to_fp16()
learn50_f.fine_tune(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.738851</td>
#       <td>0.363691</td>
#       <td>0.106225</td>
#       <td>01:09</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.432296</td>
#       <td>0.339850</td>
#       <td>0.102165</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.461415</td>
#       <td>0.308943</td>
#       <td>0.099459</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.253852</td>
#       <td>0.286665</td>
#       <td>0.077131</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.113184</td>
#       <td>0.262142</td>
#       <td>0.072395</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.059674</td>
#       <td>0.229596</td>
#       <td>0.058863</td>
#       <td>01:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn50_2 = cnn_learner(dls, resnet50, pretrained=True, metrics=error_rate)
learn50_2.fine_tune(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.763221</td>
#       <td>0.378578</td>
#       <td>0.112314</td>
#       <td>01:06</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.403505</td>
#       <td>0.357885</td>
#       <td>0.100135</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.424347</td>
#       <td>0.368915</td>
#       <td>0.100812</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.247662</td>
#       <td>0.360403</td>
#       <td>0.095399</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.117212</td>
#       <td>0.270061</td>
#       <td>0.073748</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.066451</td>
#       <td>0.243485</td>
#       <td>0.065629</td>
#       <td>01:10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## The answer is hidden under here

# %%
learn = cnn_learner(data, resnet50, pretrained=True, metrics=error_rate)

# %%
learn.lr_find()

# %%
learn.fit_one_cycle(5, lr_max=slice(3e-4, 3e-3))

# %%
learn.save('resnet50')

# %%
learn.load('resnet50')
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=4e-4)

# %%
learn.save('resnet50')
